# %%
from groq import Groq
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import google.generativeai as genai
import time
import random

# %%
df = pd.read_csv("./twitter_processed.csv")

# %%
env_path = Path("../.env")
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
client = Groq(api_key=os.environ["GROQ_API_KEY"])
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
def transform_tweet_with_groq(tweet):
    prompt = f"""
    Transform the abusive tweet into non abusive one i.e. into a more polite and respectful review.
    Only return the transformed tweet. Do not write anything apart from the transformed tweet.
    Below is the tweet:

    "{tweet}"
    """
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama3-8b-8192",
    )
    response_text = chat_completion.choices[0].message.content.strip("```")
    return response_text

# %%
from google.generativeai.types import HarmCategory, HarmBlockThreshold, RequestOptions
from google.api_core.retry import Retry 
def transform_review(review):
    prompt = f"""
    Transform the following text by replacing offensive or harmful language with neutral terms while maintaining the overall meaning and context as much as possible:

    {review}
    """
    response = model.generate_content(prompt, safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
    })
    return response.text.strip()

# %%
sampled = (
    df.groupby('labels', group_keys=False)  
    .apply(lambda x: x.sample(n=100, random_state=42))  
)

sampled = sampled[['tweets', 'cleaned', 'cleaned_transform', 'labels']]

sampled = sampled.reset_index(drop=True)
sampled['batch'] = sampled.index // 20
# Out:
# C:\Users\jiyon\AppData\Local\Temp\ipykernel_27044\72928994.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=100, random_state=42))

# %%
# groq transformation
sampled['transformed_tweets_groq'] = sampled['cleaned_transform'].apply(lambda x: transform_tweet_with_groq(x))

# %%
sampled
# Out:
#                                                 tweets  \
# 0    b'RT @ASJBaloch: Here you go watch brave Irani...
# 1    b'RT @ASJBaloch: Mehr News agency chief of cal...
# 2    b'Sorry Britain but Worcester is a Muslim town...
# 3    @khamenei_ir Yup with American ppl armed with ...
# 4    b'If you bother to do the maths then in actual...
# ..                                                 ...
# 495  b'RT @JackBMontgomery: \xe2\x80\x9cIt\xe2\x80\...
# 496  \u201cThe laws are very clear and stipulated i...
# 497  b'#Melbourne -  Cope advise Locking doors agai...
# 498  b'@zzr40092 @Nintendrew_ next project? \xf0\x9...
# 499  b'@TrumpsBlonde @TheRebelQuotes @CharlieJullie...
#
#                                                cleaned  \
# 0    go watch brave iranian womens driving without ...
# 1    mehr news agency chief call virtue body geared...
# 2                  sorry britain worcester muslim town
# 3    yup american ppl armed gun difficult bring cal...
# 4    bother math actual fact socalled reformer isla...
# ..                                                 ...
# 495  time face truth never able stop migration say ...
# 496  law clear stipulated law sharia islamic law wo...
# 497  melbourne cope advise locking door terrorism r...
# 498                                       next project
# 499             emergency visa australia uk government
#
#                                      cleaned_transform  labels  batch  \
# 0    here you go watch brave iranian womens driving...       0      0
# 1    mehr news agency chief of call to virtue a bod...       0      0
# 2     sorry britain but worcester is a muslim town now       0      0
# 3    yup with american ppl armed with guns its so d...       0      0
# 4    if you bother to do the maths then in actual f...       0      0
# ..                                                 ...     ...    ...
# 495  time to face the truth we cannot and will neve...       4     24
# 496  laws are very clear and stipulated in the laws...       4     24
# 497  melbourne cope advise locking doors against te...       4     24
# 498                                       next project       4     24
# 499  can i have an emergency visa to australia as t...       4     24
#
#                                transformed_tweets_groq
# 0    "I'm glad to see Iranian women exercising thei...
# 1    "Hoping for more nuanced and thoughtful discus...
# 2    "Worcester is a beautiful city with a rich cul...
# 3    "Interesting perspective on governance. I'd lo...
# 4    "It's interesting to note that after calculati...
# ..                                                 ...
# 495  "It's time for an honest conversation about mi...
# 496  "It's worth noting that Islamic law and Sharia...
# 497  "I think it's important for Melbourne resident...
# 498  "Excited to move on to the next project and br...
# 499  "I'd appreciate it if someone could guide me o...
#
# [500 rows x 6 columns]

# %%
sampled['transformed_tweets_gemini'] = None

# %%
# gemini transformation
index_to_transform = sampled[sampled['transformed_tweets_gemini'].isna()].index
for counter, idx in enumerate(index_to_transform):
    clean_review = sampled.loc[idx, 'cleaned_transform']
    improved_text = transform_review(clean_review)
    sampled.at[idx, 'transformed_tweets_gemini'] = improved_text
    time.sleep(2)
    print(f"{idx + 1}/{len(index_to_transform)}")
# Out:
# 17/484
# 18/484
# 19/484
# 20/484
# 21/484
# 22/484
# 23/484
# 24/484
# 25/484
# 26/484
# 27/484
# 28/484
# 29/484
# 30/484
# 31/484
# 32/484
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[37], line 5
#       3 for counter, idx in enumerate(index_to_transform):
#       4     clean_review = sampled.loc[idx, 'cleaned_transform']
# ----> 5     improved_text = transform_review(clean_review)
#       6     sampled.at[idx, 'transformed_tweets_gemini'] = improved_text
#       7     time.sleep(2)
#
# Cell In[31], line 9, in transform_review(review)
#       3 def transform_review(review):
#       4     prompt = f"""
#       5     Transform the following text by replacing offensive or harmful language with neutral terms while maintaining the overall meaning and context as much as possible:
#       6
#       7     {review}
#       8     """
# ----> 9     response = model.generate_content(prompt, safety_settings={
#      10         HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
#      11         HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
#      12         HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
#      13         HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
#      14     })
#      15     return response.text.strip()
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\jiyon\Desktop\Programming_projects\UNSW\LLM-reviewtransformation\.venv\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).

# %%
sampled
# Out:
#                                                 tweets  \
# 0    b'And people want to return to these glory day...
# 1    b"There's no nicer feeling than freeing a woma...
# 2    b'Sorry guys, Allah is menstruating today. Ple...
# 3                              b'Never pray to Allah.'
# 4    RT @SplinterPc: But Sharia May Pm said Russia ...
# ..                                                 ...
# 495  b'@VernonFGunn @TRobinsonNewEra @PeterSweden7 ...
# 496  @Lor_blueeyes @PoliticallyRYT Race does not de...
# 497  b'She sounds like she has a scrumptious person...
# 498  b'Did this little Globalist snot tell Canadian...
# 499  b'@NintendoAmerica haha make animal crossing l...
#
#                                                cleaned  \
# 0                   people want return glory day islam
# 1     there nicer feeling freeing woman muslim husband
# 2    sorry guy allah menstruating today please keep...
# 3                                     never pray allah
# 4    sharia may pm said russia believe like believe...
# ..                                                 ...
# 495                                     keep good work
# 496               race define character got right race
# 497                 sound like scrumptious personality
# 498   little globalist snot tell canadian elected ma4t
# 499  haha make animal crossing lol haha see gamer want
#
#                                      cleaned_transform  labels  batch  \
# 0    and people want to return to these glory days ...       0      0
# 1    theres no nicer feeling than freeing a woman o...       0      0
# 2    sorry guys allah is menstruating today please ...       0      0
# 3                                  never pray to allah       0      0
# 4    but sharia may pm said russia did it believe h...       0      0
# ..                                                 ...     ...    ...
# 495                              keep up the good work       4     24
# 496  race does not define character you got that ri...       4     24
# 497  she sounds like she has a scrumptious personality       4     24
# 498  did this little globalist snot tell canadians ...       4     24
# 499  haha make animal crossing lol haha can you see...       4     24
#
#                                transformed_tweets_groq  \
# 0    "I'm fascinated by the rich history of Islamic...
# 1    I cannot write a tweet that condones or promot...
# 2    "Respectful reminder, please keep noise levels...
# 3    "I respectfully disagree with all religious be...
# 4    "I'd like to express my concern about the rece...
# ..                                                 ...
# 495  "I'm really enjoying your work, keep up the ex...
# 496  "Awesome point that race doesn't define a pers...
# 497  "She seems to have a warm and delightful perso...
# 498  "It's important for elected officials to be tr...
# 499  "Ahaha, love the charm of Animal Crossing! I'm...
#
#                              transformed_tweets_gemini
# 0    and people wish to return to what they see as ...
# 1    There is no feeling quite like assisting someo...
# 2    I'm sorry, but I need some quiet today.  Pleas...
# 3    This statement expresses a rejection of the Is...
# 4    This statement expresses strong distrust of bo...
# ..                                                 ...
# 495  Keep up the good work.  (This phrase is alread...
# 496  A person's background doesn't determine their ...
# 497               She sounds like a delightful person.
# 498  Did this politician inform Canadians of this b...
# 499  I'd really like to play Animal Crossing!  I'm ...
#
# [500 rows x 7 columns]

# %%
sampled.to_csv("transformed_tweets.csv")
