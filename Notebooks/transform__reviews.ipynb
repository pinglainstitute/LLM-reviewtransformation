# %% [markdown]
# # Data Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import google.generativeai as genai
from google.generativeai import GenerativeModel
import pandas as pd
import json
import time
from google.colab import userdata
from time import sleep
import os
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
reviews_df = pd.read_csv("/content/reviews_processed.csv")

# %%
reviews_df = reviews_df[reviews_df['y']==1]

# %%
reviews_df = reviews_df.reset_index(drop=True)

# %%
# reviews_df = pd.read_csv('/content/drive/MyDrive/researchintern/new_reviews_abusive.csv')

# %%
reviews_df['y'].value_counts()
# Out:
# y
# 1    17326
# Name: count, dtype: int64

# %%
reviews_df = reviews_df[:500]
reviews_df
# Out:
#                                                   Text  y  \
# 0         cocksucker before you piss around on my work  1
# 1    hey what is it talk what is it an exclusive gr...  1
# 2    bye do not look come or think of comming back ...  1
# 3    you are gay or antisemmitian archangel white t...  1
# 4               fuck your filthy mother in the ass dry  1
# ..                                                 ... ..
# 495  thanks for doing the bidding of the troublemak...  1
# 496  smarojit chakravarty i know your facebook prof...  1
# 497                to donate to this group of buffoons  1
# 498         niggah hey fool whyd you delete my article  1
# 499  did you look at the contributions of the edito...  1
#
#                                          clean_reviews
# 0                          cocksucker piss around work
# 1    hey talk exclusive group wp talibanswho good d...
# 2              bye look come think comming back tosser
# ...

# %%
# Split the DataFrame into batches of 25
batch_size = 25
num_batches = len(reviews_df) // batch_size

# Loop through each batch and save it as a CSV file
for batch_num in range(num_batches):
    start_idx = batch_num * batch_size
    end_idx = start_idx + batch_size
    batch_df = reviews_df.iloc[start_idx:end_idx].copy()

    # Export the batch to CSV
    batch_filename = f'/content/drive/MyDrive/researchintern/gemini_nottransformed{batch_num+1}.csv'
    batch_df.to_csv(batch_filename, index=False)

    print(f'Exported batch {batch_num + 1} to {batch_filename}')
# Out:
# Exported batch 1 to /content/drive/MyDrive/researchintern/gemini_nottransformed1.csv
# Exported batch 2 to /content/drive/MyDrive/researchintern/gemini_nottransformed2.csv
# Exported batch 3 to /content/drive/MyDrive/researchintern/gemini_nottransformed3.csv
# Exported batch 4 to /content/drive/MyDrive/researchintern/gemini_nottransformed4.csv
# Exported batch 5 to /content/drive/MyDrive/researchintern/gemini_nottransformed5.csv
# Exported batch 6 to /content/drive/MyDrive/researchintern/gemini_nottransformed6.csv
# Exported batch 7 to /content/drive/MyDrive/researchintern/gemini_nottransformed7.csv
# Exported batch 8 to /content/drive/MyDrive/researchintern/gemini_nottransformed8.csv
# Exported batch 9 to /content/drive/MyDrive/researchintern/gemini_nottransformed9.csv
# Exported batch 10 to /content/drive/MyDrive/researchintern/gemini_nottransformed10.csv
# Exported batch 11 to /content/drive/MyDrive/researchintern/gemini_nottransformed11.csv
# ...

# %%
reviews_df_1=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed1.csv')
reviews_df_2=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed2.csv')
reviews_df_3=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed3.csv')
reviews_df_4=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed4.csv')
reviews_df_5=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed5.csv')
reviews_df_6=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed6.csv')
reviews_df_7=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed7.csv')
reviews_df_8=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed8.csv')
reviews_df_9=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed9.csv')
reviews_df_10=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed10.csv')
reviews_df_11=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed11.csv')
reviews_df_12=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed12.csv')
reviews_df_13=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed13.csv')
reviews_df_14=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed14.csv')
reviews_df_15=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed15.csv')
reviews_df_16=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed16.csv')
reviews_df_17=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed17.csv')
reviews_df_18=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed18.csv')
reviews_df_19=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed19.csv')
reviews_df_20=pd.read_csv('/content/drive/MyDrive/researchintern/gemini_nottransformed20.csv')

# %% [markdown]
# # GEMINI API

# %%
# !pip install -q -U google-generativeai

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# ...

# %%
genai.configure(api_key="AIzaSyDEzQBmam-xfaxYfav3FHwQpaS6tkGsU1E")
model = genai.GenerativeModel('gemini-2.5-pro')

# %%
reviews_df_20
# Out:
#                                                  Text  y  \
# 0    yes the money quote is that i am fucking piss...  1
# 1   november utc fuck off your accusations are bas...  1
# 2   just face the truth you can not escape it user...  1
# 3    dude are you stupid yankees said hes a hero t...  1
# 4   you are sick bastard and hope get your lesson ...  1
# 5   you have been banned by wikzilla you trollish ...  1
# 6   if you admins can block me for sockpuppetry th...  1
# 7              asshole yep you suck jesus of suberbia  1
# 8    hello come on be a man ooooh i am going to bl...  1
# 9          gay sex demiurge loves it in his irish ass  1
# 10   well thank you for spouting your ignorant mou...  1
# 11  listen dumbass i didnt do any anything to the ...  1
# 12  hey dick cheese editing an article is not vand...  1
# 13  like i say i am happy to discuss with you but ...  1
# 14  my page aaa your just a mean old bullshitting ...  1
# ...

# %%
# Function to transform a single review
from google.generativeai.types import HarmCategory, HarmBlockThreshold
def transform_review(review):
    prompt = f"""
    Transform the following text by replacing offensive or harmful language with neutral terms while maintaining the overall meaning and context as much as possible:

    {review}
    """
    response = model.generate_content(prompt, safety_settings={
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
    })
    return response.text.strip()

# %%
reviews_df_20['improved_text'] = ''# replace with batch number

# %%
# Process each review individually
for idx, row in reviews_df_20.iterrows():# replace with batch no
    clean_review = row['Text']
    improved_text = transform_review(clean_review)
    reviews_df_20.at[idx, 'improved_text'] = improved_text #replace with batch no.

    # Pause to avoid hitting API limits
    time.sleep(10)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 760.92ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1139/2951278151.py in <cell line: 0>()
#       2 for idx, row in reviews_df_20.iterrows():# replace with batch no
#       3     clean_review = row['Text']
# ----> 4     improved_text = transform_review(clean_review)
#       5     reviews_df_20.at[idx, 'improved_text'] = improved_text #replace with batch no.
#       6
#
# /tmp/ipykernel_1139/1014549434.py in transform_review(review)
#       7     {review}
#       8     """
# ----> 9     response = model.generate_content(prompt, safety_settings={
#      10         HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
#      11         HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
#
# ...

# %%
reviews_df_20
# Out:
#                                                  Text  y  \
# 0   it is like you have never opened a history boo...  1
# 1   white standards in latin america are a joke so...  1
# 2                                           shitskins  1
# 3   azov niggers are most likely proud to be meatg...  1
# 4                               u are a stupid nigger  1
# 5   i remember a couple years back some negres ape...  1
# 6   attack the fucking jews that put them out if y...  1
# 7   fuck you nigger this is the most important jew...  1
# 8                   kill all redditors with no excuse  1
# 9                    hohols are subhumans we told you  1
# 10  you are a wellpoising kike open borders for is...  1
# 11  so a tranny is more of a man than you heckling...  1
# 12  you are retarded if you think russia would not...  1
# 13  whites invented science and that is why they a...  1
# 14   my dream comes true berlin nukedplease mr putler  1
# ...

# %%
output_filename = '/content/drive/MyDrive/researchintern/gemini_transformed_reviews_batch20.csv'#replace with batch no.
reviews_df_20.to_csv(output_filename, index=False)#replace with batch no.

# %% [markdown]
# # Groq API

# %%
import os
from groq import Groq

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.8 MB/s eta 0:00:00
# ...

# %%
os.environ["GROQ_API_KEY"] = "" #YOUR API KEY
client = Groq(api_key=os.environ["GROQ_API_KEY"])

# %%
reviews_df_20['improved_text']=''

# %%
# Function to transform a single review
def transform_review_with_groq(review):
    prompt = f"""
    Transform the abusive review into non abusive one i.e. into a more polite and respectful review.
    Below is the review:

    "{review}"
    """
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama3-8b-8192",
    )
    response_text = chat_completion.choices[0].message.content.strip("```")
    return response_text

# %%
for idx, row in reviews_df_20.iterrows():
    clean_review = row['Text']
    improved_text = transform_review_with_groq(clean_review)
    reviews_df_20.at[idx, 'improved_text'] = improved_text

    # time.sleep(2)

# %%
reviews_df_20
# Out:
#                                                  Text  y  \
# 0   it is like you have never opened a history boo...  1
# 1   white standards in latin america are a joke so...  1
# 2                                           shitskins  1
# 3   azov niggers are most likely proud to be meatg...  1
# 4                               u are a stupid nigger  1
# 5   i remember a couple years back some negres ape...  1
# 6   attack the fucking jews that put them out if y...  1
# 7   fuck you nigger this is the most important jew...  1
# 8                   kill all redditors with no excuse  1
# 9                    hohols are subhumans we told you  1
# 10  you are a wellpoising kike open borders for is...  1
# 11  so a tranny is more of a man than you heckling...  1
# 12  you are retarded if you think russia would not...  1
# 13  whites invented science and that is why they a...  1
# 14   my dream comes true berlin nukedplease mr putler  1
# ...

# %%
output_filename = '/content/drive/MyDrive/researchintern/groq_transformed_reviews_batch20.csv'
reviews_df_20.to_csv(output_filename, index=False)
